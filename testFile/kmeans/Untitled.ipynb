# %%
import numpy as np
from sklearn.cluster import KMeans
data = np.random.rand(100, 2) #生成一个随机数据，样本大小为100, 特征数为3
print('data',data)

#假如我要构造一个聚类数为3的聚类器
estimator = KMeans(n_clusters=3)#构造聚类器
result = estimator.fit_predict(data)
print(result)
estimator.fit(data)#聚类
label_pred = estimator.labels_ #获取聚类标签
centroids = estimator.cluster_centers_ #获取聚类中心
inertia = estimator.inertia_ # 获取聚类准则的总和
print(estimator.cluster_centers_.tolist())
# Out:
# data [[0.62872936 0.93548373]
#  [0.62623182 0.20152508]
#  [0.11177966 0.75297382]
#  [0.16758382 0.24124768]
#  [0.03366168 0.03517566]
#  [0.45484485 0.61629752]
#  [0.8318202  0.64991958]
#  [0.65187314 0.04591732]
#  [0.43991654 0.68880616]
#  [0.24722264 0.480426  ]
#  [0.31278377 0.86190943]
#  [0.82030474 0.4815133 ]
#  [0.90792643 0.37901012]
#  [0.01364413 0.49415314]
#  [0.37062586 0.50833365]
#  [0.06959444 0.57877068]
#  [0.73520226 0.52002054]
#  [0.29706967 0.1199002 ]
#  [0.52748288 0.55752361]
#  [0.60013932 0.80910854]
#  [0.78633413 0.65204569]
#  [0.46571857 0.31802907]
#  [0.41329086 0.45951029]
#  [0.16706141 0.93138828]
#  [0.99979319 0.87550478]
#  [0.90059903 0.89020084]
#  [0.98377049 0.35704929]
#  [0.94481473 0.98772413]
#  [0.8820415  0.30657809]
#  [0.25807956 0.79616075]
#  [0.89208632 0.11973857]
#  [0.53840306 0.61101068]
#  [0.27693403 0.8293477 ]
#  [0.86056824 0.94626917]
#  [0.76507762 0.17829583]
#  [0.27899841 0.07864572]
# ...

# %%
a = [[410.2199556616289, 411.07189858243964], [435.8062911526941, 391.01960071452623], [454.1148903023774, 314.1777116115892], [478.6114529847346, 383.92654172384687], [409.1151205609805, 385.75774768449645], [470.6904731932627, 395.17097303749495], [443.08683511775837, 308.9779298988888], [432.59131755858755, 297.3420820563496], [385.45532543002804, 306.8581377885827], [360.24695367391405, 362.7831207427484], [379.15241304824485, 324.96688696424536], [398.95333953495805, 326.4632204214962], [385.1127479573661, 335.8164582027698], [345.16165527828315, 313.2649957108624], [381.2977048511335, 336.12521354046805], [403.800365101945, 313.81883827600586], [466.7708818263519, 231.8062813043748], [449.57061588872807, 264.8574471600891], [437.2164917546391, 220.30515460335303], [413.60400313667935, 222.00478679612013], [407.79317866664906, 292.94817740711665], [490.0681040958683, 248.78872129142877], [441.62804200867186, 276.82099696167694], [445.6161918425132, 262.9942813573742], [482.9935144335013, 280.71972358093603], [425.4688624000679, 263.04150500477755]]
b = [[462.05336842390057, 362.1332207055792], [465.5838565626071, 339.35172737934204], [469.5106535289864, 373.98422262051577]]
a + b
# Out:
# [[410.2199556616289, 411.07189858243964],
#  [435.8062911526941, 391.01960071452623],
#  [454.1148903023774, 314.1777116115892],
#  [478.6114529847346, 383.92654172384687],
#  [409.1151205609805, 385.75774768449645],
#  [470.6904731932627, 395.17097303749495],
#  [443.08683511775837, 308.9779298988888],
#  [432.59131755858755, 297.3420820563496],
#  [385.45532543002804, 306.8581377885827],
#  [360.24695367391405, 362.7831207427484],
#  [379.15241304824485, 324.96688696424536],
#  [398.95333953495805, 326.4632204214962],
#  [385.1127479573661, 335.8164582027698],
#  [345.16165527828315, 313.2649957108624],
#  [381.2977048511335, 336.12521354046805],
#  [403.800365101945, 313.81883827600586],
#  [466.7708818263519, 231.8062813043748],
#  [449.57061588872807, 264.8574471600891],
#  [437.2164917546391, 220.30515460335303],
#  [413.60400313667935, 222.00478679612013],
#  [407.79317866664906, 292.94817740711665],
#  [490.0681040958683, 248.78872129142877],
# ...
